# %%
import numpy as np
import pandas as pd
import xarray as xr

# %%
features_target = pd.read_csv("../data/processed/features_target.csv")

# %%
features_target.target.value_counts()
# Out:
# target
# 0.0    126852
# 1.0      6675
# Name: count, dtype: int64
